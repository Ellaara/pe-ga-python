# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Salaries.csv')

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data['BasePay'].plot()
# Out:
# <AxesSubplot:>

# %%
# Fixing random state for reproducibility

import numpy as np

np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
#artist record sales for the year
artists = ['Cardi B', 'Drake', 'The Stallion', 'Lil Baby', 'Camilla Cabello']
sales = [150, 300, 650, 400, 950]

#plot these on a bar chart
fig, ax = plt.subplots()
width = 0.5


ax.bar(artists, sales, width, label = 'artists')

ax.set_ylabel('sales')
ax.set_title('How much each artist sold?')

plt.show()
